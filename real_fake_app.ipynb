# %% [markdown]
# # Model Deployment

# %%
import streamlit as st
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer

# Load the best model
with open("best_model.pkl", "rb") as file:
    model = pickle.load(file)

# Load the TF-IDF vectorizer
with open("tfidf_vectorizer.pkl", "rb") as vec_file:
    vectorizer = pickle.load(vec_file)

# Streamlit App
st.title("Fake News Detector")
st.write("This application classifies news articles as **Fake News** or **Real News**.")

# User Input
user_input = st.text_area("Enter a news article:")

# Predict Button
if st.button("Classify"):
    if user_input.strip():
        # Transform and predict
        user_input_tfidf = vectorizer.transform([user_input])
        prediction = model.predict(user_input_tfidf)[0]
        result = "Real News" if prediction == 1 else "Fake News"
        st.success(f"Prediction: **{result}**")
    else:
        st.error("Please enter a news article for classification.")
# Out:
# 2024-11-27 12:55:02.029 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-27 12:55:02.215
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-11-27 12:55:02.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-27 12:55:02.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-27 12:55:02.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-27 12:55:02.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-27 12:55:02.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-27 12:55:02.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-27 12:55:02.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-27 12:55:02.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-27 12:55:02.239 Session state does not function when running a script without `streamlit run`
# 2024-11-27 12:55:02.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-27 12:55:02.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-27 12:55:02.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-27 12:55:02.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-27 12:55:02.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-27 12:55:02.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
